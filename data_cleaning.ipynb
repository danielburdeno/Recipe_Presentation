# %% [markdown]
# ## Data Preprocessing

# %%
# Importing the libraries needed
import pandas as pd
import numpy as np
import ast
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load the data
recipes = pd.read_csv('data/RAW_recipes.csv')
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231637 non-null  int64
#  2   minutes         231637 non-null  int64
#  3   contributor_id  231637 non-null  int64
#  4   submitted       231637 non-null  object
#  5   tags            231637 non-null  object
#  6   nutrition       231637 non-null  object
#  7   n_steps         231637 non-null  int64
#  8   steps           231637 non-null  object
#  9   description     226658 non-null  object
#  10  ingredients     231637 non-null  object
#  11  n_ingredients   231637 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 21.2+ MB

# %%
recipes.describe()
# Out:
#                   id       minutes  contributor_id        n_steps  \
# count  231637.000000  2.316370e+05    2.316370e+05  231637.000000
# mean   222014.708984  9.398546e+03    5.534885e+06       9.765499
# std    141206.635626  4.461963e+06    9.979141e+07       5.995128
# min        38.000000  0.000000e+00    2.700000e+01       0.000000
# 25%     99944.000000  2.000000e+01    5.690500e+04       6.000000
# 50%    207249.000000  4.000000e+01    1.736140e+05       9.000000
# 75%    333816.000000  6.500000e+01    3.982750e+05      12.000000
# max    537716.000000  2.147484e+09    2.002290e+09     145.000000
#
#        n_ingredients
# count  231637.000000
# mean        9.051153
# std         3.734796
# min         1.000000
# 25%         6.000000
# 50%         9.000000
# 75%        11.000000
# max        43.000000

# %%
recipes.isna().sum()
# Out:
# name                 1
# id                   0
# minutes              0
# contributor_id       0
# submitted            0
# tags                 0
# nutrition            0
# n_steps              0
# steps                0
# description       4979
# ingredients          0
# n_ingredients        0
# dtype: int64

# %%
# Going to drop nulls as I want description to be able to display to the user
recipes = recipes.dropna()
recipes.isna().sum()
# Out:
# name              0
# id                0
# minutes           0
# contributor_id    0
# submitted         0
# tags              0
# nutrition         0
# n_steps           0
# steps             0
# description       0
# ingredients       0
# n_ingredients     0
# dtype: int64

# %%
# Need to look at all the tags, to be used as content features
# Currently a string, need to convert to list
recipes['tags'] = recipes['tags'].apply(ast.literal_eval)
tags = recipes['tags'].explode()
tags
# Out:
# 0         60-minutes-or-less
# 0               time-to-make
# 0                     course
# 0            main-ingredient
# 0                    cuisine
#                  ...
# 231636               dietary
# 231636          comfort-food
# 231636            taste-mood
# 231636                 sweet
# 231636    number-of-servings
# Name: tags, Length: 4045919, dtype: object

# %%
len(tags.unique())
# Out:
# 552

# %%
tag_counts = tags.value_counts()
tags_filtered = tag_counts[tag_counts >  10000]
tags_filtered
# Out:
# tags
# preparation        225568
# time-to-make       220353
# course             213602
# main-ingredient    166456
# dietary            160444
#                     ...
# beverages           10913
# sweet               10503
# savory              10428
# potluck             10313
# potatoes            10052
# Name: count, Length: 80, dtype: int64

# %%
# Nutrition information (calories (#), total fat (PDV), sugar (PDV) , sodium (PDV) , protein (PDV) , saturated fat (PDV), total carbohydrates (PDV))
# Currently a string, need to convert to list then make into seperate columns
recipes['nutrition'] = recipes['nutrition'].apply(ast.literal_eval)
recipes[['calories', 'fat', 'sugar', 'sodium', 'protein', 'saturated_fat', 'carbohydrates']] = recipes['nutrition'].apply(pd.Series)
recipes = recipes.drop(columns=['nutrition'])
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  n_steps  \
# 0  [60-minutes-or-less, time-to-make, course, mai...       11
# 1  [30-minutes-or-less, time-to-make, course, mai...        9
# 2  [time-to-make, course, preparation, main-dish,...        6
# 3  [60-minutes-or-less, time-to-make, course, mai...       11
# 4  [weeknight, time-to-make, course, main-ingredi...        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  calories  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7      51.5
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6     173.4
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13     269.8
# 3  ['spreadable cheese with garlic and herbs', 'n...             11     368.1
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8     352.9
#
#     fat  sugar  sodium  protein  saturated_fat  carbohydrates
# 0   0.0   13.0     0.0      2.0            0.0            4.0
# 1  18.0    0.0    17.0     22.0           35.0            1.0
# 2  22.0   32.0    48.0     39.0           27.0            5.0
# 3  17.0   10.0     2.0     14.0            8.0           20.0
# 4   1.0  337.0    23.0      3.0            0.0           28.0

# %%
# Want to look at how specific steps are, can I use this as a content feature without heavy NLP?
# Currently a string, need to convert to list
recipes['steps'] = recipes['steps'].apply(ast.literal_eval)
recipes['steps'][0]
# Out:
# ['make a choice and proceed with recipe',
#  'depending on size of squash , cut into half or fourths',
#  'remove seeds',
#  'for spicy squash , drizzle olive oil or melted butter over each cut squash piece',
#  'season with mexican seasoning mix ii',
#  'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece',
#  'season with sweet mexican spice mix',
#  'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin',
#  'be careful not to burn the squash especially if you opt to use sugar or butter',
#  'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking',
#  'if desired , season with salt']

# %%
# I want to use inredients as a content feature as well to search for recipes
# Currently a string, need to convert to list
recipes['ingredients'] = recipes['ingredients'].apply(ast.literal_eval)
recipes['ingredients'][0]
# Out:
# ['winter squash',
#  'mexican seasoning',
#  'mixed spice',
#  'honey',
#  'butter',
#  'olive oil',
#  'salt']

# %%
# Looking at counts, lots of one off ingredients will limit based on count, same as tags
ingredients = recipes['ingredients'].explode()
ing_counts = ingredients.value_counts()
ing_counts
# Out:
# ingredients
# salt                         83781
# butter                       53788
# sugar                        43419
# onion                        38168
# water                        34060
#                              ...
# low-sodium wheat crackers        1
# capicola-mozzarella roll         1
# citrus ponzu soy sauce           1
# asiago cheese rolls              1
# nepitella                        1
# Name: count, Length: 14758, dtype: int64

# %%
# Limit to ingredients that appear more than 2000 times
ing_filetered = ing_counts[ing_counts > 2000]
ing_filetered
# Out:
# ingredients
# salt                83781
# butter              53788
# sugar               43419
# onion               38168
# water               34060
#                     ...
# beef broth           2045
# shallot              2029
# lemon, juice of      2019
# ground coriander     2012
# fresh mushrooms      2009
# Name: count, Length: 173, dtype: int64

# %%
# Something to consider for future steps, some ingredients are very similar, could be standardised with NLP
# Is this something I actually want to standardise? chicken broth vs. chicken breast?
# Need to consider this during the ingredient search
for ing in list(ing_filetered.index):
    if 'chicken' in ing:
        print(ing)
# Out:
# chicken broth
# chicken stock
# boneless skinless chicken breasts
# chicken breasts
# chicken

# %%
# Function to check if a row contains a value and return a boolean
# Will help split out ingredients and tags into seperate columns
def check_values(row, values):
    return pd.Series({value: value in row for value in values})

# %%
# Create new columns for each ingredient in the filtered list
new_cols_ing = recipes['ingredients'].apply(check_values, values=list(ing_filetered.index))
new_cols_ing
# Out:
#          salt  butter  sugar  onion  water   eggs  olive oil  flour  \
# 0        True    True  False  False  False  False       True  False
# 1       False   False  False  False  False   True      False  False
# 2        True   False  False  False   True  False      False  False
# 3        True   False  False  False  False  False       True  False
# 4        True   False   True  False  False  False      False  False
# ...       ...     ...    ...    ...    ...    ...        ...    ...
# 231632  False   False   True   True  False  False       True  False
# 231633   True   False  False  False  False  False      False  False
# 231634   True   False  False  False  False  False      False  False
# 231635  False    True  False  False  False  False      False  False
# 231636  False   False  False  False  False   True      False   True
#
#         garlic cloves   milk  ...  cooking spray  skim milk  cream  chicken  \
# 0               False  False  ...          False      False  False    False
# 1               False   True  ...          False      False  False    False
# 2               False  False  ...          False      False  False    False
# 3               False  False  ...          False      False  False    False
# 4               False  False  ...          False      False  False    False
# ...               ...    ...  ...            ...        ...    ...      ...
# 231632           True  False  ...          False      False  False    False
# 231633          False  False  ...          False      False  False    False
# 231634          False  False  ...          False      False  False    False
# 231635          False  False  ...          False      False  False    False
# 231636          False  False  ...          False      False  False    False
#
#         warm water  beef broth  shallot  lemon, juice of  ground coriander  \
# 0            False       False    False            False             False
# 1            False       False    False            False             False
# 2            False       False    False            False             False
# 3            False       False    False            False             False
# 4            False       False    False            False             False
# ...            ...         ...      ...              ...               ...
# 231632       False       False    False            False             False
# 231633       False       False    False            False             False
# 231634       False       False    False            False             False
# 231635       False       False    False            False             False
# 231636       False       False    False            False             False
#
#         fresh mushrooms
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 231632            False
# 231633            False
# 231634            False
# 231635            False
# 231636            False
#
# [226657 rows x 173 columns]

# %%
# Creating new columns for each tag in the filtered list
new_cols_tag = recipes['tags'].apply(check_values, values=list(tags_filtered.index))
new_cols_tag
# Out:
#         preparation  time-to-make  course  main-ingredient  dietary   easy  \
# 0              True          True    True             True     True   True
# 1              True          True    True             True     True   True
# 2              True          True    True            False     True  False
# 3              True          True    True             True     True   True
# 4              True          True    True             True     True  False
# ...             ...           ...     ...              ...      ...    ...
# 231632         True          True    True             True    False   True
# 231633         True          True    True            False     True   True
# 231634         True          True    True             True    False   True
# 231635         True          True    True            False     True  False
# 231636         True          True    True            False     True  False
#
#         occasion  cuisine  low-in-something  main-dish  ...  \
# 0           True     True             False      False  ...
# 1           True     True             False       True  ...
# 2          False    False             False       True  ...
# 3           True    False             False      False  ...
# 4           True     True             False      False  ...
# ...          ...      ...               ...        ...  ...
# 231632     False     True             False      False  ...
# 231633     False    False             False      False  ...
# 231634     False    False             False      False  ...
# 231635     False    False             False      False  ...
# 231636      True    False             False      False  ...
#
#         free-of-something  condiments-etc  high-in-something  soups-stews  \
# 0                   False           False              False        False
# 1                   False           False              False        False
# 2                   False           False              False        False
# 3                   False           False              False        False
# 4                   False            True              False        False
# ...                   ...             ...                ...          ...
# 231632              False           False              False         True
# 231633              False            True              False        False
# 231634              False           False              False        False
# 231635              False           False               True        False
# 231636              False           False              False        False
#
#         technique  beverages  sweet  savory  potluck  potatoes
# 0           False      False  False   False    False     False
# 1           False      False  False   False    False     False
# 2           False      False  False   False    False     False
# 3           False      False  False   False    False      True
# 4            True      False  False   False    False     False
# ...           ...        ...    ...     ...      ...       ...
# 231632      False      False  False   False    False     False
# 231633      False      False  False   False    False     False
# 231634      False      False  False   False    False     False
# 231635      False      False  False   False    False     False
# 231636      False      False   True   False    False     False
#
# [226657 rows x 80 columns]

# %%
# Brining together ingredients and tags into one dataframe
tags_ings = pd.concat([new_cols_ing, new_cols_tag], axis=1)
tags_ings.head()
# Out:
#     salt  butter  sugar  onion  water   eggs  olive oil  flour  garlic cloves  \
# 0   True    True  False  False  False  False       True  False          False
# 1  False   False  False  False  False   True      False  False          False
# 2   True   False  False  False   True  False      False  False          False
# 3   True   False  False  False  False  False       True  False          False
# 4   True   False   True  False  False  False      False  False          False
#
#     milk  ...  free-of-something  condiments-etc  high-in-something  \
# 0  False  ...              False           False              False
# 1   True  ...              False           False              False
# 2  False  ...              False           False              False
# 3  False  ...              False           False              False
# 4  False  ...              False            True              False
#
#    soups-stews  technique  beverages  sweet  savory  potluck  potatoes
# 0        False      False      False  False   False    False     False
# 1        False      False      False  False   False    False     False
# 2        False      False      False  False   False    False     False
# 3        False      False      False  False   False    False      True
# 4        False       True      False  False   False    False     False
#
# [5 rows x 253 columns]

# %%
# Bringing togather the features I want to use in the content based filtering and removing the columns I don't want
recipes_feat = recipes.drop(columns=['contributor_id', 'submitted', 'tags', 'steps', 'description',
                                     'ingredients', 'name', 'n_steps', 'n_ingredients', 'minutes'])
recipes_feat = pd.concat([recipes_feat, tags_ings], axis=1)
recipes_feat.head()
# Out:
#        id  calories   fat  sugar  sodium  protein  saturated_fat  \
# 0  137739      51.5   0.0   13.0     0.0      2.0            0.0
# 1   31490     173.4  18.0    0.0    17.0     22.0           35.0
# 2  112140     269.8  22.0   32.0    48.0     39.0           27.0
# 3   59389     368.1  17.0   10.0     2.0     14.0            8.0
# 4   44061     352.9   1.0  337.0    23.0      3.0            0.0
#
#    carbohydrates   salt  butter  ...  free-of-something  condiments-etc  \
# 0            4.0   True    True  ...              False           False
# 1            1.0  False   False  ...              False           False
# 2            5.0   True   False  ...              False           False
# 3           20.0   True   False  ...              False           False
# 4           28.0   True   False  ...              False            True
#
#    high-in-something  soups-stews  technique  beverages  sweet  savory  \
# 0              False        False      False      False  False   False
# 1              False        False      False      False  False   False
# 2              False        False      False      False  False   False
# 3              False        False      False      False  False   False
# 4              False        False       True      False  False   False
#
#    potluck  potatoes
# 0    False     False
# 1    False     False
# 2    False     False
# 3    False      True
# 4    False     False
#
# [5 rows x 261 columns]

# %%
# Slight overlap in tags and ingredients, will remove duplicates
duplicate_columns = recipes_feat.columns[recipes_feat.columns.duplicated()].tolist()
duplicate_columns
# Out:
# ['sugar', 'chicken', 'cheese', 'potatoes']

# %%
# Sanity check for duplicate column names
recipes_feat.columns.value_counts()
# Out:
# cheese              2
# sugar               2
# chicken             2
# potatoes            2
# sesame seeds        1
#                    ..
# ketchup             1
# balsamic vinegar    1
# buttermilk          1
# cilantro            1
# potluck             1
# Name: count, Length: 257, dtype: int64

# %%
# Removing duplicate columns
recipes_feat_clean = recipes_feat.loc[:, ~recipes_feat.columns.duplicated()]
recipes_feat_clean.columns.value_counts()
# Out:
# id                     1
# bananas                1
# cucumber               1
# cold water             1
# sesame seeds           1
#                       ..
# ground black pepper    1
# ketchup                1
# balsamic vinegar       1
# buttermilk             1
# potluck                1
# Name: count, Length: 257, dtype: int64

# %%
# Save feature matrix as parquet file
recipes_feat_clean.to_parquet('data/recipes_feat.parquet')

# %%
# For size limitations seperating the content features and the tags and ingredients
recipes_ingtag = recipes.drop(columns=['name', 'steps', 'description', 'contributor_id', 'submitted', 'n_ingredients', 
                                    'n_steps', 'minutes', 'calories', 'fat', 'sugar', 'sodium', 'protein',
                                    'saturated_fat', 'carbohydrates'])
recipes_ingtag.head()
# Out:
#        id                                               tags  \
# 0  137739  [60-minutes-or-less, time-to-make, course, mai...
# 1   31490  [30-minutes-or-less, time-to-make, course, mai...
# 2  112140  [time-to-make, course, preparation, main-dish,...
# 3   59389  [60-minutes-or-less, time-to-make, course, mai...
# 4   44061  [weeknight, time-to-make, course, main-ingredi...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
# Save as parquet file
recipes_ingtag.to_parquet('data/recipes_ingtag.parquet')

# %%
# Create a dataframe with steps and description
recipes_steps = recipes.drop(columns=['contributor_id', 'submitted', 'n_ingredients', 'n_steps', 'minutes', 'calories', 'fat',
                                      'sugar', 'sodium', 'protein', 'saturated_fat', 'carbohydrates', 'tags'])
recipes_steps.head()
# Out:
#                                          name      id  \
# 0  arriba   baked winter squash mexican style  137739
# 1            a bit different  breakfast pizza   31490
# 2                   all in the kitchen  chili  112140
# 3                          alouette  potatoes   59389
# 4          amish  tomato ketchup  for canning   44061
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
# 3  [place potatoes in a large pot of lightly salt...
# 4  [mix all ingredients& boil for 2 1 / 2 hours ,...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
# Save as parquet file
recipes_steps.to_parquet('data/recipes_steps.parquet')

# %% [markdown]
# ## Testing Functions for Streamlit

# %%
recipes_test = recipes_ingtag.copy()
recipes_test.head()
# Out:
#        id                                               tags  \
# 0  137739  [60-minutes-or-less, time-to-make, course, mai...
# 1   31490  [30-minutes-or-less, time-to-make, course, mai...
# 2  112140  [time-to-make, course, preparation, main-dish,...
# 3   59389  [60-minutes-or-less, time-to-make, course, mai...
# 4   44061  [weeknight, time-to-make, course, main-ingredi...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
# Need a function to match if selected tags are present in the row
# We will prompt user for specific tags, and return recipes that contain all of those tags
def all_tags_present(item_tags, selected):
    return all(string in item_tags for string in selected)

# %%
recipes_test['tag_match'] = recipes_test['tags'].apply(all_tags_present, selected=['poultry', '30-minutes-or-less'])
recipes_test = recipes_test[recipes_test['tag_match'] == True]

# %%
recipes_test.head()
# Out:
#          id                                               tags  \
# 57    32169  [30-minutes-or-less, time-to-make, course, mai...
# 75    42570  [30-minutes-or-less, time-to-make, course, mai...
# 233  219681  [30-minutes-or-less, time-to-make, course, mai...
# 336  399278  [30-minutes-or-less, time-to-make, course, mai...
# 447  371549  [30-minutes-or-less, time-to-make, course, mai...
#
#                                            ingredients  tag_match
# 57   [tomatoes, garlic, onion, button mushrooms, ho...       True
# 75   [boneless chicken breast, garlic, salt, cumin,...       True
# 233  [chicken breasts, olive oil, lemon juice, whit...       True
# 336  [cayenne pepper sauce, vegetable oil, granulat...       True
# 447  [jalapeno peppers, fresh cilantro, light beer,...       True

# %%
# Ingredient selection, will handle input with streamlit
ing_selected = ['chicken', 'lentils']

# %%
# Need to define a function that will return True if all ingredients selected are found in the matched row
def check_ingredients_df(row):
    ing_matched = row
    
    # Join all ingredients into a single lowercase string
    ingredients_str = ' '.join(str(ing).lower() for ing in ing_matched)
    
    # Check each item in all_ings
    for item in ing_selected:
        item = item.strip('s')
        if item not in ingredients_str:
            return False
    
    # If we've made it through all items without returning False, return True
    return True

# %%
# Can now apply to dataframe
recipes_test['ing_match'] = recipes_test['ingredients'].apply(check_ingredients_df)
recipes_test[recipes_test['ing_match'] == True]
# Out:
#             id                                               tags  \
# 16018   204669  [30-minutes-or-less, time-to-make, course, mai...
# 46564    66735  [30-minutes-or-less, time-to-make, course, mai...
# 123030  287439  [30-minutes-or-less, time-to-make, course, mai...
# 180614  363669  [lactose, 30-minutes-or-less, time-to-make, co...
#
#                                               ingredients  tag_match  \
# 16018   [skinless chicken breasts, split peas, red len...       True
# 46564   [olive oil, onion, garlic, red lentils, chicke...       True
# 123030  [boneless skinless chicken breasts, water, tom...       True
# 180614  [whole chicken, olive oil, onion, garlic clove...       True
#
#         ing_match
# 16018        True
# 46564        True
# 123030       True
# 180614       True

# %%
# How do we want to display the steps to the user?
recipes_steps.head()
# Out:
#                                          name      id  \
# 0  arriba   baked winter squash mexican style  137739
# 1            a bit different  breakfast pizza   31490
# 2                   all in the kitchen  chili  112140
# 3                          alouette  potatoes   59389
# 4          amish  tomato ketchup  for canning   44061
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
# 3  [place potatoes in a large pot of lightly salt...
# 4  [mix all ingredients& boil for 2 1 / 2 hours ,...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
rec = recipes_steps[recipes_steps['id'] == 66735]
rec['steps'].values[0], rec['name'].values[0]
# Out:
# (['heat the oil in a non-stick saucepan over medium heat and cook the onion and garlic until softened',
#   'add the lentils and stock and bring to a boil',
#   'cover and cook for 10 minutes , or until lentils are tender',
#   'stir through the lemon juice , parsley , salt and pepper',
#   'while lentils are cooking , season the chicken with cumin',
#   'heat a non-stick frying pan and spray with cooking oil spray',
#   'cook chicken until cooked through',
#   'serve over lentils',
#   'lamb or fish fillets can be exchanged for chicken in this recipe'],
#  'chicken with red lentils')

# %%
name = rec['name'].values[0].replace(' ', '-')
name
# Out:
# 'chicken-with-red-lentils'

# %%
# Can use some clever formatted strings to display the link (because they all follow the same format)
link = f"https://www.food.com/recipe/{name}-{rec['id'].values[0]}"
link
# Out:
# 'https://www.food.com/recipe/chicken-with-red-lentils-66735'

# %%
# We can use the feature matrix to find similar recipes to the one selected
rec_feat = recipes_feat_clean[recipes_feat_clean['id'] == 66735]
rec_feat = rec_feat.drop(columns=['id']).values.reshape(1, -1)

# Using cosine similarity to compare feature vectors
cosine_sim = cosine_similarity(rec_feat, recipes_feat_clean.drop(columns=['id']))
sim_scores = list(zip(recipes_feat_clean['id'].values, cosine_sim[0]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
sim_scores = sim_scores[1:6]
rec_indices = [i[0] for i in sim_scores]

recs = recipes_steps[recipes_steps['id'].isin(rec_indices)][['id', 'name', 'description']]
recs
# Out:
#             id                                               name  \
# 44912   292894                   chicken noodle goulash  abs diet
# 107617  359825                honey mustard cracker crumb chicken
# 150669  161093                          oven baked fish and chips
# 168905  458924  quick double tomato chicken with artichoke hea...
# 179112   56760                                salmon potato boats
#
#                                               description
# 44912   my husband does the abs diet. this is one of t...
# 107617  this is a healthier version of fried chicken. ...
# 150669  from family circle, uk.  a healthy version of ...
# 168905  entered for safe-keeping, this is almost a "cu...
# 179112  another recipe i've had for years from the bac...
